# %% [markdown]
# # Phyling API
#
# To use this notebook, you need to create a `.env` file with:
#
# ```env
# PHYLING_API_KEY=your_api_key
#
# # Server API:   https://api.app.phyling.fr
# # Maxi-Hub API: 192.168.1.42:5001
# PHYLING_API_URL="https://api.app.phyling.fr"
# ```

# %%
import json
import time
import logging
import os
from dotenv import load_dotenv

from phyling.api import PhylingAPI
from phyling.api import PhylingRealtime

load_dotenv()
# Out:
# True

# %% [markdown]
# # API connection

# %%
# Create API and Realtime instances
api = PhylingAPI(
    api_key=os.getenv("PHYLING_API_KEY"),
    url=os.getenv("PHYLING_API_URL", "https://api.app.phyling.fr/")
)

realtime = PhylingRealtime(api)

# %%
# Start auto-updating device list every socketIO update
realtime.autoUpdateDeviceList(True)

# %%
# Print the device list (will update automatically in the background)
print(realtime.getDeviceList())
# Out:
# [{'number': 10300378, 'name': 'Maxi 378', 'is_connected': True, 'state': 'record'}]

# %%
# Enable auto-updates for device status, indicator, and data for the first connected device
number = realtime.getDeviceList()[0]["number"]
realtime.autoUpdateDeviceStatus(number=number, enabled=True)
realtime.autoUpdateDeviceIndicator(number=number, enabled=True)
realtime.autoUpdateDeviceData(number=number, enabled=True)

# %%
# Print the device status (will update automatically in the background)
print(realtime.getDeviceStatus(number=number))
# Out:
# {'battery': 41, 'client': {'id': 2, 'name': 'phyling'}, 'deviceRecId': 214, 'epoch': 1763629756.0, 'features': {'calib': {'cmd_get': 'v1.board.calib.get', 'cmd_set': 'v1.board.calib.set'}, 'config': {'cmd_get': 'v1.board.config.get', 'cmd_set': 'v1.board.config.set'}, 'device_info': {'cmd_get': 'v1.board.device_info.get', 'cmd_set': 'v1.board.device_info.set'}, 'firmware_update': {'cmd': 'v1.board.firmware_update'}, 'logs': {'cmd_get': 'v1.logs.get', 'cmd_list': 'v1.logs.list'}, 'record': {'cmd_start': 'v1.record.rec.start', 'cmd_stop': 'v1.record.rec.stop'}, 'restart': {'cmd': 'v1.board.restart'}, 'scenario': {'cmd_start': 'v1.record.scenario.start', 'cmd_stop': 'v1.record.scenario.stop'}, 'shutdown': {'cmd': 'v1.board.shutdown'}, 'time_set': {'cmd': 'v1.board.time.set'}, 'wifi': {'cmd_get': 'v1.board.wifi.get', 'cmd_set': 'v1.board.wifi.set'}}, 'group': {'id': 1, 'name': 'phyling'}, 'is_connected': True, 'modules': {'gps': {'id': 1, 'is_connected': True, 'realtime': True, 'type': 'gps'}, 'imu': {'id': 2, 'is_connected': True, 'realtime': True, 'type': 'imu'}}, 'name': 'Maxi 378', 'needFirmwareUpdate': False, 'number': 10300378, 'realtime_data_keys': [{'description': '', 'label': 'gps.gpstimeUs', 'name': 'gps.gpstimeUs', 'precision': 3, 'unit': 'us', 'yRange': []}, {'description': '', 'label': 'gps.gpsTimeAccuracyNs', 'name': 'gps.gpsTimeAccuracyNs', 'precision': 3, 'unit': 'ns', 'yRange': []}, {'description': '', 'label': 'gps.longitude', 'name': 'gps.longitude', 'precision': 3, 'unit': '', 'yRange': []}, {'description': '', 'label': 'gps.latitude', 'name': 'gps.latitude', 'precision': 3, 'unit': '', 'yRange': []}, {'description': '', 'label': 'gps.speed', 'name': 'gps.speed', 'precision': 3, 'unit': 'm/s', 'yRange': []}, {'description': '', 'label': 'gps.altitude', 'name': 'gps.altitude', 'precision': 3, 'unit': 'm', 'yRange': []}, {'description': '', 'label': 'gps.heading', 'name': 'gps.heading', 'precision': 3, 'unit': 'deg', 'yRange': []}, {'description': '', 'label': 'gps.nSat', 'name': 'gps.nSat', 'precision': 3, 'unit': '', 'yRange': []}, {'description': '', 'label': 'gps.PDOP', 'name': 'gps.PDOP', 'precision': 3, 'unit': '', 'yRange': []}, {'description': '', 'label': 'imu.acc_y', 'name': 'imu.acc_y', 'precision': 3, 'unit': 'm/s^2', 'yRange': []}, {'description': '', 'label': 'imu.acc_z', 'name': 'imu.acc_z', 'precision': 3, 'unit': 'm/s^2', 'yRange': []}, {'description': '', 'label': 'imu.gyro_x', 'name': 'imu.gyro_x', 'precision': 3, 'unit': 'deg/s', 'yRange': []}, {'description': '', 'label': 'imu.gyro_y', 'name': 'imu.gyro_y', 'precision': 3, 'unit': 'deg/s', 'yRange': []}, {'description': '', 'label': 'imu.gyro_z', 'name': 'imu.gyro_z', 'precision': 3, 'unit': 'deg/s', 'yRange': []}, {'description': '', 'label': 'imu.acc_x', 'name': 'imu.acc_x', 'precision': 3, 'unit': '', 'yRange': [-25, 15]}], 'realtime_indicator_keys': [{'description': {'en': 'Cadence', 'fr': 'Cadence'}, 'enabled': True, 'name': 'cadence', 'precision': 1, 'type': 'number', 'unit': {'en': 'spm', 'fr': 'cpm'}}, {'description': {'en': 'Time for 500m', 'fr': 'Tps au 500m'}, 'enabled': True, 'name': 'T_500m', 'precision': -1, 'type': 'number', 'unit': ''}], 'recTime': 43.515, 'selectionStartTime': 0, 'sport': {'display_name': 'Aviron', 'name': 'aviron'}, 'startRecTimeSinceEpoch': 1763629714.051, 'state': 'record', 'timezone': 'Europe/Paris', 'user': {'active': True, 'firstname': 'Tim', 'id': 10, 'lastname': 'Nicolas', 'mail': 'tim.nicolas@phyling.fr'}, 'version': 'v7.0.1'}

# %%
# Print the device state only
print(realtime.getDeviceStatus(number=number)["state"])
# Out:
# record

# %%
# Print the available RPC methods
print(realtime.getDeviceStatus(number=number)["features"])
# Out:
# {'calib': {'cmd_get': 'v1.board.calib.get', 'cmd_set': 'v1.board.calib.set'}, 'config': {'cmd_get': 'v1.board.config.get', 'cmd_set': 'v1.board.config.set'}, 'device_info': {'cmd_get': 'v1.board.device_info.get', 'cmd_set': 'v1.board.device_info.set'}, 'firmware_update': {'cmd': 'v1.board.firmware_update'}, 'logs': {'cmd_get': 'v1.logs.get', 'cmd_list': 'v1.logs.list'}, 'record': {'cmd_start': 'v1.record.rec.start', 'cmd_stop': 'v1.record.rec.stop'}, 'restart': {'cmd': 'v1.board.restart'}, 'scenario': {'cmd_start': 'v1.record.scenario.start', 'cmd_stop': 'v1.record.scenario.stop'}, 'shutdown': {'cmd': 'v1.board.shutdown'}, 'time_set': {'cmd': 'v1.board.time.set'}, 'wifi': {'cmd_get': 'v1.board.wifi.get', 'cmd_set': 'v1.board.wifi.set'}}

# %%
# Perform a RPC request
realtime.executeRPC(
    number=number,
    method="v1.record.rec.start",
    params={}
)

# %%
# Print the device indicator (will update automatically in the background - only on record/scenario states)
print(realtime.getDeviceIndicator(number=number))
# Out:
# {'number': 10300378, 'recTime': 51.959, 'indicators': {'cadence': {'x': 51.678889, 'y': 0}, 'T_500m': {'x': 51.559823, 'y': 'NaN'}}}

# %%
# Print the latest realtime data (will update automatically in the background - only on record/scenario states)
lastRtData = realtime.getDeviceData(number=number)
print(lastRtData)
# Out:
# {'number': 10300378, 'recTime': 56.939, 'data': {'imu': {'acc_x': [0.359046, 0.363833, 0.301599, 0.330322, 0.31596, 0.320748], 'acc_y': [0.215428, 0.191491, 0.205853, 0.205853, 0.215428, 0.186704], 'acc_z': [9.952756, 9.914457, 9.866585, 9.967117, 9.924032, 9.919245], 'gyro_x': [2.59, 2.66, 2.66, 2.66, 2.59, 2.73], 'gyro_y': [-4.97, -4.97, -4.97, -4.83, -4.83, -4.9], 'gyro_z': [-1.96, -1.96, -2.03, -1.96, -1.96, -1.96], 'T': [56.673, 56.693, 56.713, 56.733, 56.753, 56.773]}, 'gps': {'gpstimeUs': [1763629770799947], 'gpsTimeAccuracyNs': [268], 'longitude': [2.098548], 'latitude': [48.731577], 'speed': [0.018], 'altitude': [138.574997], 'heading': [271.869629], 'nSat': [4], 'PDOP': [11.81], 'T': [56.744]}}, 'selections': []}

# %%
# Continuously print new realtime data as it arrives
ONLY_FIRST = True
lastRecTime = 0
while True:
    status = realtime.getDeviceStatus(number=number)
    rtData = realtime.getDeviceData(number=number)
    now = time.time()
    if rtData["recTime"] <= lastRecTime:
        continue
    lastRecTime = rtData["recTime"]
    dataStr = f"[{rtData['recTime']:6.3f}] "
    for modname, modcontent in rtData.get("data", {}).items():
        latency = now - status['startRecTimeSinceEpoch'] - rtData["data"][modname]["T"][-1]
        dataStr +=  f" | latency: {int(latency * 1000):4d}ms"
        for key, value in modcontent.items():
            if key in ["T"]:
                continue
            if len(dataStr) > 0:
                dataStr += " | "
            dataStr += f"{modname}.{key}: {value[-1]:.2f}"
            if ONLY_FIRST:
                break
    if len(dataStr) > 0:
        print(dataStr)
    time.sleep(0.01)
# Out:
# [114.827]  | latency:  236ms | imu.acc_x: 0.28
# [114.994]  | latency:  259ms | imu.acc_x: 0.28 | latency:  333ms | gps.gpstimeUs: 1763629828799895.00
# [115.113]  | latency:  214ms | imu.acc_x: 0.30 | latency:  212ms | gps.gpstimeUs: 1763629828999896.00
# [115.229]  | latency:  208ms | imu.acc_x: 0.30
# [115.402]  | latency:  262ms | imu.acc_x: 0.24 | latency:  336ms | gps.gpstimeUs: 1763629829199895.00
# [115.519]  | latency:  219ms | imu.acc_x: 0.33 | latency:  328ms | gps.gpstimeUs: 1763629829299895.00
# [115.642]  | latency:  215ms | imu.acc_x: 0.28 | latency:  249ms | gps.gpstimeUs: 1763629829499895.00
# [115.763]  | latency:  214ms | imu.acc_x: 0.31 | latency:  283ms | gps.gpstimeUs: 1763629829599895.00
# [115.927]  | latency:  276ms | imu.acc_x: 0.30 | latency:  360ms | gps.gpstimeUs: 1763629829699895.00
# [116.051]  | latency:  248ms | imu.acc_x: 0.48 | latency:  282ms | gps.gpstimeUs: 1763629829899895.00
# [116.171]  | latency:  248ms | imu.acc_x: 0.32 | latency:  272ms | gps.gpstimeUs: 1763629829999895.00
# [116.290]  | latency:  226ms | imu.acc_x: 0.36 | latency:  230ms | gps.gpstimeUs: 1763629830199894.00
# [116.408]  | latency:  219ms | imu.acc_x: -0.54 | latency:  233ms | gps.gpstimeUs: 1763629830299894.00
# [116.581]  | latency:  243ms | imu.acc_x: 0.15 | latency:  292ms | gps.gpstimeUs: 1763629830399894.00
# [116.695]  | latency:  244ms | imu.acc_x: 1.58 | latency:  308ms | gps.gpstimeUs: 1763629830499894.00
# [116.813]  | latency:  225ms | imu.acc_x: -0.97 | latency:  244ms | gps.gpstimeUs: 1763629830699893.00
# [116.929]  | latency:  203ms | imu.acc_x: -2.89 | latency:  252ms | gps.gpstimeUs: 1763629830799893.00
# [117.100]  | latency:  242ms | imu.acc_x: -3.87
# [117.217]  | latency:  224ms | imu.acc_x: -3.83 | latency:  322ms | gps.gpstimeUs: 1763629830999894.00
# [117.327]  | latency:  219ms | imu.acc_x: -4.76 | latency:  267ms | gps.gpstimeUs: 1763629831199893.00
# [117.498]  | latency:  245ms | imu.acc_x: -9.08 | latency:  329ms | gps.gpstimeUs: 1763629831299893.00
# [117.614]  | latency:  234ms | imu.acc_x: -7.67 | latency:  227ms | gps.gpstimeUs: 1763629831499893.00
# [117.730]  | latency:  216ms | imu.acc_x: -3.29
# [117.850]  | latency:  240ms | imu.acc_x: -7.53 | latency:  289ms | gps.gpstimeUs: 1763629831699892.00
# [118.018]  | latency:  249ms | imu.acc_x: -6.39
# [118.131]  | latency:  234ms | gps.gpstimeUs: 1763629831999893.00 | latency:  235ms | imu.acc_x: -6.89
# [118.250]  | latency:  226ms | imu.acc_x: -3.30
# [118.421]  | latency:  277ms | imu.acc_x: -4.86 | latency:  351ms | gps.gpstimeUs: 1763629832199892.00
# [118.540]  | latency:  230ms | imu.acc_x: -3.42 | latency:  254ms | gps.gpstimeUs: 1763629832399892.00
# [118.655]  | latency:  244ms | imu.acc_x: -3.42 | latency:  283ms | gps.gpstimeUs: 1763629832499892.00
# [118.773]  | latency:  234ms | imu.acc_x: -4.62 | latency:  303ms | gps.gpstimeUs: 1763629832599892.00
# [118.946]  | latency:  246ms | imu.acc_x: -4.63 | latency:  265ms | gps.gpstimeUs: 1763629832799891.00
# [119.062]  | latency:  250ms | imu.acc_x: -5.93 | latency:  279ms | gps.gpstimeUs: 1763629832899891.00
# [119.178]  | latency:  219ms | imu.acc_x: -5.13 | latency:  278ms | gps.gpstimeUs: 1763629832999892.00
# [119.295]  | latency:  235ms | imu.acc_x: -3.08 | latency:  228ms | gps.gpstimeUs: 1763629833199891.00
# [119.465]  | latency:  252ms | imu.acc_x: -1.62
# [119.581]  | latency:  248ms | imu.acc_x: -2.90 | latency:  302ms | gps.gpstimeUs: 1763629833399891.00
# [119.700]  | latency:  215ms | imu.acc_x: -2.68 | latency:  218ms | gps.gpstimeUs: 1763629833599891.00
# [119.813]  | latency:  213ms | imu.acc_x: -2.53 | latency:  227ms | gps.gpstimeUs: 1763629833699891.00
# [119.932]  | latency:  212ms | imu.acc_x: -2.60
# [120.090]  | latency:  260ms | imu.acc_x: -2.52 | latency:  329ms | gps.gpstimeUs: 1763629833899891.00
# [120.203]  | latency:  233ms | imu.acc_x: -2.49 | latency:  291ms | gps.gpstimeUs: 1763629833999891.00
# [120.320]  | latency:  226ms | imu.acc_x: -2.74 | latency:  255ms | gps.gpstimeUs: 1763629834199890.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       4 while True:
#       5     status = realtime.getDeviceStatus(number=number)
# ----> 6     rtData = realtime.getDeviceData(number=number)
#       7     now = time.time()
#       8     if rtData["recTime"] <= lastRecTime:
#
# File ~/Documents/Phyling/git/PhylingApp/phyling/phyling/api/realtime.py:289, in PhylingRealtime.getDeviceData(self, number)
#     283     else:
#     284         self.sio.topicUnsubscribe(
#     285             topic=f"app/device/{number}/data/json/all",
#     286             event="app/device/data/json/all",
#     287         )
# --> 289 def getDeviceData(self, number: int) -> dict | None:
#     290     """
#     291     Returns the data of a specific device.
#     292     :param number: The ID of the device.
#     293     :return: The data of the device or {} if not found.
#     294     """
#     295     return self.devicesData.get(
#     296         number,
#     297         {
#    (...)
#     302         },
#     303     )
#
# KeyboardInterrupt:

# %%
# Continuously print new realtime indicators as they arrive
# {'number': 10200300, 'recTime': 178.123, 'indicators': {'acc_x': {'x': 177.842491, 'y': 0.2968113739043474}}}
ONLY_FIRST = False
lastRecTime = 0
while True:
    status = realtime.getDeviceStatus(number=number)
    rtIndicators = realtime.getDeviceIndicator(number=number)
    now = time.time()
    if rtIndicators["recTime"] <= lastRecTime:
        continue
    lastRecTime = rtIndicators["recTime"]
    dataStr = f"[{rtIndicators['recTime']:6.3f}] "
    for indname, indcontent in rtIndicators.get("indicators", {}).items():
        latency = now - status['startRecTimeSinceEpoch'] - rtIndicators["indicators"][indname]["x"]
        dataStr +=  f"latency: {int(latency * 1000):4d}ms {indname}: {indcontent['y']:.2f}"
        if ONLY_FIRST:
            break
    if len(dataStr) > 0:
        print(dataStr)
    time.sleep(0.01)
# Out:
# [382.254] latency:  899ms acc_x: 0.29
# [382.840] latency:  370ms acc_x: 0.31
# [383.373] latency:  337ms acc_x: 0.31
# [384.025] latency:  338ms acc_x: 0.30
# [384.564] latency:  337ms acc_x: 0.32
# [385.082] latency:  347ms acc_x: 0.32
# [385.730] latency:  339ms acc_x: 0.51
# [386.391] latency:  364ms acc_x: -9.34
# [386.999] latency:  298ms acc_x: -9.11
# [387.524] latency:  301ms acc_x: -8.89
# [388.079] latency:  315ms acc_x: -9.15
# [388.593] latency:  332ms acc_x: -1.32
# [389.138] latency:  329ms acc_x: -1.35
# [389.796] latency:  339ms acc_x: -1.33
# [390.353] latency:  368ms acc_x: -1.26
# [390.860] latency:  349ms acc_x: -1.20
# [391.473] latency:  320ms acc_x: -1.02
# [392.022] latency:  310ms acc_x: -0.82
# [392.555] latency:  323ms acc_x: -0.63
# [393.060] latency:  306ms acc_x: -3.08
# [393.606] latency:  325ms acc_x: -8.37
# [394.395] latency:  847ms acc_x: -8.73
# [394.901] latency:  336ms acc_x: -7.11
# [395.409] latency:  322ms acc_x: 9.62
# [395.949] latency:  329ms acc_x: 0.26
# [396.613] latency:  331ms acc_x: 0.30
# [397.141] latency:  344ms acc_x: 0.30
# [397.655] latency:  328ms acc_x: 0.30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 6
#       4 lastRecTime = 0
#       5 while True:
# ----> 6     status = realtime.getDeviceStatus(number=number)
#       7     rtIndicators = realtime.getDeviceIndicator(number=number)
#       8     now = time.time()
#
# File ~/Documents/Phyling/git/PhylingApp/phyling/phyling/api/realtime.py:134, in PhylingRealtime.getDeviceStatus(self, number)
#     128 def getDeviceStatus(self, number: int) -> dict | None:
#     129     """
#     130     Returns the status of a specific device.
#     131     :param number: The ID of the device.
#     132     :return: The status of the device or None if not found.
#     133     """
# --> 134     return self.devicesStatus.get(number, {
#     135         "number": number,
#     136         "is_connected": False,
#     137         "state": "off",
#     138     })
#
# KeyboardInterrupt:

# %%
realtime.executeRPC(
    number=number,
    method="v1.record.rec.stop",
    params={},
    wait_for_result=False
)
